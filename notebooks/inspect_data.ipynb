# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\user\\OneDrive\\Desktop\\Production_RAG\\data\\raw\\qa_crawled.csv")
print(df.columns)
print(df.head())
# Out:
# Index(['category', 'question', 'answer'], dtype='object')
#            category                                           question  \
# 0  میز خدمت و پذیرش  شرکت‌های غیردانش‌بنیان از چه خدماتی می‌توانند ...
# 1  میز خدمت و پذیرش  سقف میزان تسهیلات برای شرکت‌های دانش‌بنیان بر ...
# 2  میز خدمت و پذیرش           شركت دانش بنيان به چه شركتی گفته می شود؟
# 3  میز خدمت و پذیرش  چه شرکت‌هایی امکان استفاده از خدمات و حمایت‌ها...
# 4  میز خدمت و پذیرش  شرکت‌های دانش‌بنیان از چه خدمات و حمایت‌هایی ت...
#
#                                               answer
# 0  پاسخ: صندوق نوآوری و شکوفایی بر اساس اسناد بال...
# 1  پاسخ: میزان تسهیلات قابل ارائه به شرکت‌های دان...
# 2  پاسخ: شرکت‌هایی که توسط کارگروه ارزیابی و تشخی...
# 3  پاسخ: تمامی شرکت‌های دانش‌بنیان مورد تأیید کار...
# 4  پاسخ: خدمات و حمایت‌های صندوق در چهار دسته اصل...

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\\Users\\\user\\OneDrive\\Desktop\\Production_RAG\\data\\eval\\eval_questions.csv",
    sep="\t"
)

print(df.head())
# Out:
#                                             question  expected_row_id
# 0  ???????? ????????????? ?? ?? ?????? ????????? ...                0
# 1  ??? ????? ??????? ???? ???????? ?????????? ?? ...                1
# 2           ???? ???? ????? ?? ?? ????? ???? ???????                2
# 3  ?? ????????? ????? ??????? ?? ????? ? ????????...                3
# 4        ????? ??????????? ????? ???? ?? ?????? ????               18

# %%
import pandas as pd

df = pd.read_csv(r"C:\\Users\\\user\\OneDrive\\Desktop\\Production_RAG\\data\\eval\\eval_questions.csv")

print(df.columns)
print(df.head())
# Out:
# Index(['question', 'expected_row_id'], dtype='object')
#                                             question  expected_row_id
# 0  شرکت‌های غیردانش‌بنیان از چه خدماتی می‌توانند ...                0
# 1  سقف میزان تسهیلات برای شرکت‌های دانش‌بنیان بر ...                1
# 2           شرکت دانش بنیان به چه شرکتی گفته می‌شود؟                2
# 3  چه شرکت‌هایی امکان استفاده از خدمات و حمایت‌ها...                3
# 4        خدمات توانمندسازی صندوق شامل چه خدماتی است؟               18

# %%
import pandas as pd

df = pd.read_csv(r"C:\\Users\\\user\\OneDrive\\Desktop\\Production_RAG\\data\\eval\\eval_questions_2.csv")

print(df.columns)
print(df.head())
# Out:
# Index(['question', 'expected_row_id'], dtype='object')
#                                             question  expected_row_id
# 0  شرکت‌های غیردانش‌بنیان از چه خدماتی می‌توانند ...                0
# 1  سقف میزان تسهیلات برای شرکت‌های دانش‌بنیان بر ...                1
# 2           شرکت دانش بنیان به چه شرکتی گفته می شود؟                2
# 3  چه شرکت‌هایی امکان استفاده از خدمات و حمایت‌ها...                3
# 4        خدمات توانمندسازی صندوق شامل چه خدماتی است؟               18
